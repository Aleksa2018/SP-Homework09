# %%
import matplotlib.pyplot as plt 
from scipy.misc import imread,imsave
import numpy as np
# %matplotlib inline

rgb_image = imread("index.jpg")
plt.imshow(rgb_image)
# Out:
# c:\users\aleksa\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
def convert_to_grayscale(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

    
gray = convert_to_grayscale(rgb_image)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()
